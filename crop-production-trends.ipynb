# %% [markdown]
# <div style="background-color: #17a526; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 10px;">🌽🌾 Crop Production Analysis🌾🌽📈</h1>
#     <p style="text-align: center; font-size: 18px; color: white;">Explore data, discover insights, and unleash the power of analysis.</p>
# </div>

# %% [markdown]
# <img src="https://wallpapercave.com/wp/wp3115847.jpg" alt="Crop Image" style="box-shadow: 5px 5px 5px grey;">

# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('/kaggle/input/crop-production-1996-to-2021/world_food_production.csv')
df1 = pd.read_csv('/kaggle/input/crop-production-1996-to-2021/rice_ countries.csv')

# %%
df1.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# <div style="background-color: #17a526; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 10px;"> Data Analysis </h1>.

# %%
fig1 = px.line(df, x='year', y='rice_production', title='Trend in Rice Production Over the Years', labels={'rice_production': 'Rice Production (Million Tons)'})

fig1.update_layout(
    plot_bgcolor='black',  
    paper_bgcolor='black',  
    font=dict(color='white'),
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False)
)
fig1.update_traces(line=dict(color='white'))
fig1.show()

# %%
fig2 = px.line(df, x='year', y='wheat_production', title='Wheat Production Distribution Over the Years', labels={'wheat_production': 'Wheat Production (Million Tons)'})

fig2.update_layout(
    plot_bgcolor='#ffbf00', 
    paper_bgcolor='#ffbf00', 
    font=dict(color='black'),  
    xaxis=dict(showgrid=False, title='Year'),
    yaxis=dict(showgrid=False, title='Wheat Production (Million Tons)')
)

fig2.update_traces(line=dict(color='black')) 
fig2.show()

# %%
fig3 = px.line(df, x='year', y='vegetable_production', title='Vegetable Production Distribution Over the Years', labels={'vegetable_production': 'Vegetable Production (Million Tons)'})

fig3.update_layout(
    plot_bgcolor='#6cf5c2', 
    paper_bgcolor='#6cf5c2', 
    font=dict(color='black'),  
    xaxis=dict(showgrid=False, title='Year'),
    yaxis=dict(showgrid=False, title='Vegetable Production (Million Tons)')
)

fig3.update_traces(line=dict(color='black')) 
fig3.show()

# %%
fig4 = px.scatter(df, x='rice_production', y='wheat_production', trendline='ols', title='Correlation Between Rice and Wheat Production', labels={'rice_production': 'Rice Production (Million Tons)', 'wheat_production': 'Wheat Production (Million Tons)'})

fig4.update_layout(
    plot_bgcolor='#80ee39', 
    paper_bgcolor='#80ee39', 
    font=dict(color='black'),  
    xaxis=dict(showgrid=False, title='Rice Production (Million Tons)'),
    yaxis=dict(showgrid=False, title='Wheat Production (Million Tons)')
)

fig4.update_traces(marker=dict(color='black'), selector=dict(mode='markers')) 
fig4.show()

# %%
fig1 = px.line(df1, x='Country', y=['2020', '2010', '2000', '1990'], title='Rice Production Trend (Million Tons)')

fig1.update_layout(
    plot_bgcolor='#e2e5df', 
    paper_bgcolor='#e2e5df', 
    font=dict(color='black'),  
    xaxis=dict(showgrid=False, title='Country'),
    yaxis=dict(showgrid=False, title='Rice Production (Million Tons)')
)

line_colors = ['blue', 'green', 'red', 'purple']

for i, color in enumerate(line_colors):
    fig1.update_traces(selector=dict(name=f'{"2020" if i==0 else str(2020 - i*10)}'), line=dict(color=color))

fig1.show()

# %%
top10_1990 = df1.nlargest(10, '1990')
fig2 = px.bar(top10_1990, x='Country', y='1990', title='Rice Production in 1990 (Million Tons)')
fig2.show()

# %%
fig3 = px.pie(df1, names='Country', values='2020', title='Distribution of Rice Production in 2020')
fig3.show()

# %% [markdown]
# <div style="background-color: #17a526; padding: 20px; border-radius: 8px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.2); margin-top: 20px;">
#     <h1 style="text-align: center; color: #ffffff; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 15px;"><strong>😊 Thank You for Exploring This Notebook!😊</strong></h1>
#     <h2 style="text-align: center; color: #ffffff; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 15px;"><strong>If you enjoyed it and found value in the content, please consider giving it an Upvote.Your support means a lot to me and encourages me to create more helpful notebooks.</strong></h2>
# </div>
